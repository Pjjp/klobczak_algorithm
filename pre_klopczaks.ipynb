# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
table_2 = pd.read_csv('2_column.csv')

# %%
table_2['A'].var()
# Out:
# 400.07807258604765

# %%
table_2['B'].var()
# Out:
# 400.3404575399737

# %%
table_2['A'].hist()

# %%
np.median(table_2['A'])
# Out:
# 100.0

# %%
table_2['B'].hist()

# %%
np.median(table_2['B'])
# Out:
# 200.0

# %%
sns.jointplot(x='A', y='B', data=table_2)

# %%
(table_2[table_2['B'] > 200])['B']

# %%
tb_a = (table_2[table_2['B'] > 200])

# %%
sns.jointplot(x='A', y='B', data=tb_a)

# %%
tb_a.count().sum()
# Out:
# 960740

# %%
tb_a.count()
# Out:
# A    480370
# B    480370
# dtype: int64
